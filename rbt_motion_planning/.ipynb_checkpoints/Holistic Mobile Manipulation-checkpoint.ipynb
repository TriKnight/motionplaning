# %%
# !pip3 install quadprog
# !pip3 install spatialmath-python
# Out:
# /bin/bash: /home/robotlab/anaconda3/envs/rlgpu/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Requirement already satisfied: quadprog in /home/robotlab/anaconda3/envs/rbt/lib/python3.10/site-packages (0.1.11)
# Requirement already satisfied: numpy in /home/robotlab/anaconda3/envs/rbt/lib/python3.10/site-packages (from quadprog) (1.23.1)
# /bin/bash: /home/robotlab/anaconda3/envs/rlgpu/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Requirement already satisfied: spatialmath-python in /home/robotlab/anaconda3/envs/rbt/lib/python3.10/site-packages (1.0.0)
# Requirement already satisfied: ansitable in /home/robotlab/anaconda3/envs/rbt/lib/python3.10/site-packages (from spatialmath-python) (0.9.6)
# Requirement already satisfied: matplotlib in /home/robotlab/anaconda3/envs/rbt/lib/python3.10/site-packages (from spatialmath-python) (3.5.2)
# Requirement already satisfied: colored in /home/robotlab/anaconda3/envs/rbt/lib/python3.10/site-packages (from spatialmath-python) (1.4.3)
# Requirement already satisfied: scipy in /home/robotlab/anaconda3/envs/rbt/lib/python3.10/site-packages (from spatialmath-python) (1.8.1)
# Requirement already satisfied: numpy in /home/robotlab/anaconda3/envs/rbt/lib/python3.10/site-packages (from spatialmath-python) (1.23.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/robotlab/anaconda3/envs/rbt/lib/python3.10/site-packages (from matplotlib->spatialmath-python) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /home/robotlab/anaconda3/envs/rbt/lib/python3.10/site-packages (from matplotlib->spatialmath-python) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /home/robotlab/anaconda3/envs/rbt/lib/python3.10/site-packages (from matplotlib->spatialmath-python) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/robotlab/anaconda3/envs/rbt/lib/python3.10/site-packages (from matplotlib->spatialmath-python) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /home/robotlab/anaconda3/envs/rbt/lib/python3.10/site-packages (from matplotlib->spatialmath-python) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/robotlab/anaconda3/envs/rbt/lib/python3.10/site-packages (from matplotlib->spatialmath-python) (4.34.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/robotlab/anaconda3/envs/rbt/lib/python3.10/site-packages (from matplotlib->spatialmath-python) (1.4.3)
# Requirement already satisfied: six>=1.5 in /home/robotlab/anaconda3/envs/rbt/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->spatialmath-python) (1.16.0)

# %%
import swift
import roboticstoolbox as rtb
import spatialgeometry as sg
import spatialmath as sm
import qpsolvers as qp
import numpy as np
import math


def step_robot(r: rtb.ERobot, Tep):

    wTe = r.fkine(r.q)

    eTep = np.linalg.inv(wTe) @ Tep

    # Spatial error
    et = np.sum(np.abs(eTep[:3, -1]))

    # Gain term (lambda) for control minimisation
    Y = 0.01

    # Quadratic component of objective function
    Q = np.eye(r.n + 6)

    # Joint velocity component of Q
    Q[: r.n, : r.n] *= Y
    Q[:2, :2] *= 1.0 / et

    # Slack component of Q
    Q[r.n :, r.n :] = (1.0 / et) * np.eye(6)

    v, _ = rtb.p_servo(wTe, Tep, 1.5)

    v[3:] *= 1.3

    # The equality contraints
    Aeq = np.c_[r.jacobe(r.q), np.eye(6)]
    beq = v.reshape((6,))

    # The inequality constraints for joint limit avoidance
    Ain = np.zeros((r.n + 6, r.n + 6))
    bin = np.zeros(r.n + 6)

    # The minimum angle (in radians) in which the joint is allowed to approach
    # to its limit
    ps = 0.1

    # The influence angle (in radians) in which the velocity damper
    # becomes active
    pi = 0.9

    # Form the joint limit velocity damper
    Ain[: r.n, : r.n], bin[: r.n] = r.joint_velocity_damper(ps, pi, r.n)

    # Linear component of objective function: the manipulability Jacobian
    c = np.concatenate(
        (np.zeros(2), -r.jacobm(start=r.links[4]).reshape((r.n - 2,)), np.zeros(6))
    )

    # Get base to face end-effector
    kε = 0.5
    bTe = r.fkine(r.q, include_base=False).A
    θε = math.atan2(bTe[1, -1], bTe[0, -1])
    ε = kε * θε
    c[0] = -ε

    # The lower and upper bounds on the joint velocity and slack variable
    lb = -np.r_[r.qdlim[: r.n], 10 * np.ones(6)]
    ub = np.r_[r.qdlim[: r.n], 10 * np.ones(6)]

    # Solve for the joint velocities dq
    qd = qp.solve_qp(Q, c, Ain, bin, Aeq, beq, lb=lb, ub=ub)
    qd = qd[: r.n]

    if et > 0.5:
        qd *= 0.7 / et
    else:
        qd *= 1.4

    if et < 0.02:
        return True, qd
    else:
        return False, qd


env = swift.Swift()
env.launch(realtime=True)

ax_goal = sg.Axes(0.1)
env.add(ax_goal)

frankie = rtb.models.Frankie()
frankie.q = frankie.qr
env.add(frankie)

arrived = False
dt = 0.025

# Behind
env.set_camera_pose([-2, 3, 0.7], [-2, 0.0, 0.5])
wTep = frankie.fkine(frankie.q) * sm.SE3.Rz(np.pi)
wTep.A[:3, :3] = np.diag([-1, 1, -1])
wTep.A[0, -1] -= 4.0
wTep.A[2, -1] -= 0.25
ax_goal.T = wTep
env.step()


while not arrived:

    arrived, frankie.qd = step_robot(frankie, wTep.A)
    env.step(dt)

    # Reset bases
    base_new = frankie.fkine(frankie._q, end=frankie.links[2])
    frankie._T = base_new.A
    frankie.q[:2] = 0

env.hold()
# Out:
# ---------------------------------------------------------------------------
# NoSolverSelected                          Traceback (most recent call last)
# Input In [2], in <cell line: 109>()
#     106 env.step()
#     109 while not arrived:
# --> 111     arrived, frankie.qd = step_robot(frankie, wTep.A)
#     112     env.step(dt)
#     114     # Reset bases
#
# Input In [2], in step_robot(r, Tep)
#      69 ub = np.r_[r.qdlim[: r.n], 10 * np.ones(6)]
#      71 # Solve for the joint velocities dq
# ---> 72 qd = qp.solve_qp(Q, c, Ain, bin, Aeq, beq, lb=lb, ub=ub)
#      73 qd = qd[: r.n]
#      75 if et > 0.5:
#
# File ~/anaconda3/envs/rbt/lib/python3.10/site-packages/qpsolvers/solve_qp.py:135, in solve_qp(P, q, G, h, A, b, lb, ub, solver, initvals, sym_proj, verbose, **kwargs)
#      51 """
#      52 Solve a Quadratic Program defined as:
#      53
#    (...)
#     132 provide by ``solve_qp(P, q, G, h, solver='osqp', eps_abs=1e-4)``.
#     133 """
#     134 if solver is None:
# --> 135     raise NoSolverSelected(
#     136         "Set the `solver` keyword argument to one of the "
#     137         f"available solvers in {available_solvers}"
#     138     )
#     139 if sym_proj:
#     140     P = 0.5 * (P + P.transpose())
#
# NoSolverSelected: Set the `solver` keyword argument to one of the available solvers in ['quadprog']
